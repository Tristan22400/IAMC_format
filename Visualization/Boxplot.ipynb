# %% [markdown]
# Some <b>pyam</b> plots like Sankey are built upon <b>matplotlib</b>, so we need to import the library

# %%
import matplotlib.pyplot as plt
import pyam

# %%
# path to the results file (in IAMC format)
path = "..\\Final_script\\File_Converted\\"

try:
    # df = pd.read_csv(path + "Baseline no policies no CO2taxconverted.csv", sep=",")
    df = pyam.IamDataFrame(path + "Baseline no policies no CO2taxconverted.csv")
except:
    print("ERROR opening the file with results in IAMC format")
# Out:
# [INFO] 09:54:48 - pyam.core: Reading file ..\Final_script\File_Converted\Baseline no policies no CO2taxconverted.csv
# c:\Users\34670\.conda\envs\wiliamcformat\Lib\site-packages\pyam\utils.py:318: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(dropna=True)

# %%
# Search the variable you want to plot

# Import the library to efficiently search variables
import triesearching

# Creation of the trie (tree data structure) of our results
trie = triesearching.Trie()

for x in df.variable:
    trie.insert(x)

# Enter the prefix of the variable you want to see.
prefix = input("Enter a prefix to search for completions: ")
completions = triesearching.suggest_completions(trie, prefix)
print("Completions:", "\n".join(completions))
# Out:
# Completions: Primary Energy
# Primary Energy Intensity GDP
# Primary Energy Intensity Gdp [annual Change]
# Primary Energy Intensity Gdp [cumulative Change 2015]
# Primary Energy|Biomass|Energy Crop
# Primary Energy|Biomass|Energy Crop [per capita]
# Primary Energy|Biomass|Solids|Biomass
# Primary Energy|Biomass|Solids|Biomass [per capita]
# Primary Energy|Coal
# Primary Energy|Coal [per capita]
# Primary Energy|Gas
# Primary Energy|Gas [per capita]
# Primary Energy|Geothermal
# Primary Energy|Geothermal [per capita]
# Primary Energy|Hydro
# Primary Energy|Hydro [per capita]
# Primary Energy|New
# Primary Energy|Nuclear
# Primary Energy|Nuclear [per capita]
# Primary Energy|Ocean
# Primary Energy|Ocean [per capita]
# Primary Energy|Oil
# Primary Energy|Oil [per capita]
# Primary Energy|Renewable [Share]
# Primary Energy|Solar
# Primary Energy|Solar [per capita]
# Primary Energy|Waste
# Primary Energy|Waste [per capita]
# Primary Energy|Wind
# Primary Energy|Wind [per capita]

# %%
data = df.filter(scenario="Baseline no policies no CO2tax", variable="Emissions|CO2", region="World")

fig, ax = plt.subplots(figsize=(30, 5))
data.plot.box(x="year", ax=ax)
plt.tight_layout()
plt.show()

# There is only 1 model in this example, so we do not see uncertainty.
# Out:
# c:\Users\34670\.conda\envs\wiliamcformat\Lib\site-packages\pyam\plotting.py:727: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc=2)
